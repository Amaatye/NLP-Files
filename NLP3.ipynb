# %%
#Task 1: Basic Text Processing Pipeline
import nltk
text1= '''When Mr. Bilbo Baggins of Bag End announced that
he would shortly be celebrating his eleventy-first birthday
with a party of special magnificence, there was much talk
and excitement in Hobbiton.

Bilbo was very rich and very peculiar, and had been the wonder
of the Shire for sixty years, ever since his remarkable
disappearance and unexpected return.''' 
for text in text1:
    sentences = nltk.sent_tokenize(text1)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        tagged = nltk.pos_tag(words)
        print(tagged)
# Out:
# [('When', 'WRB'), ('Mr.', 'NNP'), ('Bilbo', 'NNP'), ('Baggins', 'NNP'), ('of', 'IN'), ('Bag', 'NNP'), ('End', 'NNP'), ('announced', 'VBD'), ('that', 'IN'), ('he', 'PRP'), ('would', 'MD'), ('shortly', 'RB'), ('be', 'VB'), ('celebrating', 'VBG'), ('his', 'PRP$'), ('eleventy-first', 'JJ'), ('birthday', 'NN'), ('with', 'IN'), ('a', 'DT'), ('party', 'NN'), ('of', 'IN'), ('special', 'JJ'), ('magnificence', 'NN'), (',', ','), ('there', 'EX'), ('was', 'VBD'), ('much', 'JJ'), ('talk', 'NN'), ('and', 'CC'), ('excitement', 'NN'), ('in', 'IN'), ('Hobbiton', 'NNP'), ('.', '.')]
# ...

# %%
text1= '''When Mr. Bilbo Baggins of Bag End announced that
he would shortly be celebrating his eleventy-first birthday
with a party of special magnificence, there was much talk
and excitement in Hobbiton.

Bilbo was very rich and very peculiar, and had been the wonder
of the Shire for sixty years, ever since his remarkable
disappearance and unexpected return.''' 
for text in text1:
    sentences = nltk.sent_tokenize(text1)
    print (sentences)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        print(words)
        tagged = nltk.pos_tag(words)
        print(tagged)
# Out:
# ['When Mr. Bilbo Baggins of Bag End announced that\nhe would shortly be celebrating his eleventy-first birthday\nwith a party of special magnificence, there was much talk\nand excitement in Hobbiton.', 'Bilbo was very rich and very peculiar, and had been the wonder\nof the Shire for sixty years, ever since his remarkable\ndisappearance and unexpected return.']
# ['When', 'Mr.', 'Bilbo', 'Baggins', 'of', 'Bag', 'End', 'announced', 'that', 'he', 'would', 'shortly', 'be', 'celebrating', 'his', 'eleventy-first', 'birthday', 'with', 'a', 'party', 'of', 'special', 'magnificence', ',', 'there', 'was', 'much', 'talk', 'and', 'excitement', 'in', 'Hobbiton', '.']
# ...

# %%
#Tweet tokenizer
from nltk.tokenize import TweetTokenizer
text= 'The party was soooo fun :D #Lessgo#BigFAM'
twtkn = TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'party', 'was', 'soooo', 'fun', ':D', '#Lessgo', '#BigFAM']

# %%
#Scrapping Data from the web
from urllib import request
url= "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)
from nltk.tokenize import word_tokenize
tokens = word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
import nltk
#download this file
f = open('tweets1.txt','r')
text = f.read()
text1 = text.split()
text2=nltk.Text(text1)
text2.concordance("good")
# Out:
# Displaying 17 of 17 matches:
# n The Signal premiere. Lotsa buyers. Good luck gang listening to the pocast ne
# so going to enjoy this shower. Feels good to have worked on a trail three time
# ose not my friend. it was not a very good day so I have a lot to do tomorrow..
# Oh why cheesecake why? You looked so good evil cake. Now metamucil. Reading: "
# utiful day so Im thinking to spend a good part of it outdoors.first stop at St
# g and ignoring my reaction to a very good friend getting fired. it's like a bi
# d HDH - url wrist sprain= damn pain. good thing it's not on my left hand. Bein
#  I bet I can throw farther than her. Good luck with that dude. Sure it will al
#  Choppers. first day of eid .. feels good Looking to buy a game called Shut th
# g. back from the ASLA 6 Congress. :) Good job ASLA CORE! I'm gonna need to ste
# tching the CNBC video of David Lear. Good job Sean! and now... off to Belize!
# ...
